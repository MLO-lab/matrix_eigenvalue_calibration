# %% [markdown]
# ## Preprocessing TriviaQA dataset into an evaluation split

# %%
import json, os, random

# %%
with open('../data/raw/TriviaQA/unfiltered-web-dev.json', 'r') as file:
    data = json.load(file)

# %%
for i, item in enumerate(data['Data']):
    item['datapoint_id']= i

# %%
random.seed(42)

# %%
sample = random.sample(data['Data'], 300)

# %%
sample[0]
# Out:
# {'Answer': {'Aliases': ['Tango (cat)',
#    'Death and state funeral of Winston Churchill',
#    'Churchillian',
#    'State funeral of Winston Churchill',
#    'Sir Winston Leonard Spencer-Churchill',
#    'Marigold Frances Churchill',
#    'Sir winston hcurchill',
#    'Winston Leonard Spencer',
#    'Winston Spencer',
#    'Winston Spencer-Churchill',
#    'Sir Churchill',
#    'Marigold Churchill',
#    'Winnie Churchill',
#    'Winston Churchill MP',
#    'Winston churchill',
#    'Prime Minister Churchill',
#    'W. Churchill',
#    'Winston Leonard Churchill',
#    'Churchill, W. S.',
#    'Sir Winston',
#    'W. S. Churchill',
#    'Winston churchilll',
#    'The Focus',
#    'Winston Churchill',
#    'The Honourable Sir Winston Spencer Churchill',
#    'Sir Winston Churchill',
#    'WINSTON CHURCHILL',
#    'Winston churchhill',
#    'Sir Winston Leonard Spencer Churchill',
#    'Churchill',
#    'Winston Spencer Churchill',
#    'Churchill, Winston',
# ...

# %%
eval_data = []
for i, item in enumerate(sample):
    eval_data.append({
        'question_id': i,
        'datapoint_id': item['datapoint_id'],
        'question': item['Question'],
        'gt_answer': item['Answer']['Value'],
    })

# %%
eval_data
# Out:
# [{'question_id': 0,
#   'datapoint_id': 10476,
#   'question': 'Who was the British Prime Minister in 1953?',
#   'gt_answer': 'Winston Churchill'},
#  {'question_id': 1,
#   'datapoint_id': 1824,
#   'question': 'The UK television drama series ‘Boys From the Black Stuff’ was set in which city?',
#   'gt_answer': 'Liverpool'},
#  {'question_id': 2,
#   'datapoint_id': 409,
#   'question': 'Who won the Ladies singles title at Wimbledon in 2004?',
#   'gt_answer': 'Maria Sharapova'},
#  {'question_id': 3,
#   'datapoint_id': 4506,
#   'question': 'Set up in 1954 as a merger of smaller groups, the Front de Libration Nationale fought a war for independence from France until 1962, when the French government signed a cease-fire agreement. The FLN became the only legal party in which country?',
#   'gt_answer': 'Algeria'},
#  {'question_id': 4,
#   'datapoint_id': 4012,
#   'question': '"""I\'m a dot in place"" has what relation to ""A decimal point""?"',
#   'gt_answer': 'Anagram'},
# ...

# %%
with open('../data/eval/TriviaQA.json', 'w') as file:
    json.dump(eval_data, file)
